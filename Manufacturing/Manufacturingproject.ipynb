# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel("C:\\Data Analytics\\EDA\\EDA PROJECTS\\manufacturing_data (2).xlsx")

# %%
df.head()
# Out:
#          Date Machine_ID Machine_Type    Shift Operator  Production_Units  \
# 0  2024-01-01         M2    Semi-Auto    Night        B               436
# 1  2024-01-02         M1    Automatic  Evening        E               565
# 2  2024-01-03         M4    Semi-Auto    Night        E               562
# 3  2024-01-04         M5    Semi-Auto    Night        B               478
# 4  2024-01-05         M1    Semi-Auto    Night        B               427
#
#    Downtime_Min Downtime_Reason  Defects Defect_Type  Raw_Material_Used  \
# 0            47     Maintenance        8        Dent                575
# 1            11     Maintenance        3     Scratch                589
# 2            15       Breakdown        7        Dent                586
# 3             9       Breakdown        8        Dent                595
# 4            58           Setup        2       Crack                579
#
#    Energy_Consumption  Temperature  Humidity Maintenance_Type  \
# ...

# %%
df.tail()
# Out:
#             Date Machine_ID Machine_Type    Shift Operator  Production_Units  \
# 4995  2024-09-07         M3    Automatic    Night        B               410
# 4996  2024-09-08         M1    Automatic    Night        B               485
# 4997  2024-09-09         M5    Automatic  Evening        C               460
# 4998  2024-09-10         M3    Semi-Auto    Night        C               470
# 4999  2024-09-11         M1    Semi-Auto      Day        B               451
#
#       Downtime_Min Downtime_Reason  Defects Defect_Type  Raw_Material_Used  \
# 4995            34           Setup       12   Alignment                613
# 4996            26           Setup        1       Crack                632
# 4997            50       Breakdown        6        Dent                641
# 4998            11     Maintenance        3     Scratch                567
# 4999            49           Setup        4     Scratch                596
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5000 non-null   str
#  1   Machine_ID          5000 non-null   str
#  2   Machine_Type        5000 non-null   str
#  3   Shift               5000 non-null   str
#  4   Operator            5000 non-null   str
#  5   Production_Units    5000 non-null   int64
#  6   Downtime_Min        5000 non-null   int64
#  7   Downtime_Reason     5000 non-null   str
#  8   Defects             5000 non-null   int64
#  9   Defect_Type         5000 non-null   str
#  10  Raw_Material_Used   5000 non-null   int64
#  11  Energy_Consumption  5000 non-null   int64
#  12  Temperature         5000 non-null   int64
#  13  Humidity            5000 non-null   int64
#  14  Maintenance_Type    5000 non-null   str
#  15  Maintenance_Cost    5000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        Production_Units  Downtime_Min      Defects  Raw_Material_Used  \
# count       5000.000000   5000.000000  5000.000000        5000.000000
# mean         501.189800     32.284600     6.531200         600.009800
# std           58.460689     16.275656     3.459049          29.129645
# min          400.000000      5.000000     1.000000         550.000000
# 25%          450.000000     18.000000     4.000000         575.000000
# 50%          502.000000     32.000000     7.000000         600.000000
# 75%          552.000000     47.000000    10.000000         625.000000
# max          600.000000     60.000000    12.000000         650.000000
#
#        Energy_Consumption  Temperature    Humidity  Maintenance_Cost  \
# count         5000.000000  5000.000000  5000.00000       5000.000000
# mean           135.146600    47.512600    32.51940       3728.265800
# std             14.764468     4.598094     4.57443       1296.261263
# ...

# %%
df.isnull()
# Out:
#        Date  Machine_ID  Machine_Type  Shift  Operator  Production_Units  \
# 0     False       False         False  False     False             False
# 1     False       False         False  False     False             False
# 2     False       False         False  False     False             False
# 3     False       False         False  False     False             False
# 4     False       False         False  False     False             False
# ...     ...         ...           ...    ...       ...               ...
# 4995  False       False         False  False     False             False
# 4996  False       False         False  False     False             False
# 4997  False       False         False  False     False             False
# 4998  False       False         False  False     False             False
# 4999  False       False         False  False     False             False
#
#       Downtime_Min  Downtime_Reason  Defects  Defect_Type  Raw_Material_Used  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                  0
# Machine_ID            0
# Machine_Type          0
# Shift                 0
# Operator              0
# Production_Units      0
# Downtime_Min          0
# Downtime_Reason       0
# Defects               0
# Defect_Type           0
# Raw_Material_Used     0
# Energy_Consumption    0
# Temperature           0
# Humidity              0
# Maintenance_Type      0
# Maintenance_Cost      0
# Production_Target     0
# Cycle_Time            0
# Rework_Units          0
# Inventory_Level       0
# dtype: int64
